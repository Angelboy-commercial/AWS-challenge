# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
# CoinName,Algorithm,IsTrading,ProofType,TotalCoinsMined,TotalCoinSupply
crypto = requests.get(url).json()
# def crypto_clean(crypto):
#     for coin in crypto['Data']:
#         name = coin['CoinName']
#         algorithm = coin['Algorithm']
#         trading = coin['IsTrading']
#         proof = coin['ProofType']
#         total_minted = coin['TotalCoinsMined']
#         total_supply = coin['TotalCoinSupply']

#     return pd.DataFrame({
#         "Name":name,
#         'Algorithm': algorithm,
#         'Currently trading': trading,
#         'ProofType': proof,
#          'Total Minted': total_minted,
#          'Supply': total_supply
#     })

crypto_df = pd.DataFrame(crypto['Data']).T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42         42             0            0           0   blockchain
# 300       300             0            0           0        token
# 365        -1             0            0           0   blockchain
# 404        -1             0            0           0   blockchain
# 433       NaN           NaN          NaN         NaN          NaN
#
#     AlgorithmType Difficulty BuiltOn  \
# 42         scrypt   0.440859     NaN
# 300           NaN        NaN     ETH
# 365           NaN        NaN     NaN
# 404           NaN        NaN     NaN
# 433           NaN        NaN     NaN
#
#                            SmartContractAddress DecimalPoints
# 42                                          NaN           NaN
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557            18
# 365                                         NaN           NaN
# 404                                         NaN           NaN
# 433                                         NaN           NaN
#
# [5 rows x 36 columns]

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# crypto_df = pd.read_csv('crypto_data.csv', index_col="CoinName")
# crypto_df = crypto_df.drop(columns=['Unnamed: 0'], axis=1)

crypto_df
# Out:
#            Id                    Url                         ImageUrl  \
# 42       4321     /coins/42/overview           /media/35650717/42.jpg
# 300    749869    /coins/300/overview          /media/27010595/300.png
# 365     33639    /coins/365/overview            /media/352070/365.png
# 404     21227    /coins/404/overview  /media/35650851/404-300x300.jpg
# 433    926547    /coins/433/overview          /media/34836095/433.png
# ...       ...                    ...                              ...
# COMM     4422   /coins/comm/overview            /media/19661/comm.png
# CRYPT    4427  /coins/crypt/overview           /media/19664/crypt.png
# CTO      6117    /coins/cto/overview             /media/19808/mrs.png
# CTX    941224    /coins/ctx/overview         /media/37747472/ctx1.png
# KART   948579   /coins/kart/overview         /media/40219116/kart.png
#
#       ContentCreatedOn   Name Symbol        CoinName               FullName  \
# 42          1427211129     42     42         42 Coin           42 Coin (42)
# 300         1517935016    300    300       300 token        300 token (300)
# 365         1480032918    365    365         365Coin          365Coin (365)
# 404         1466100361    404    404         404Coin          404Coin (404)
# 433         1541597321    433    433       433 Token        433 Token (433)
# ...                ...    ...    ...             ...                    ...
# COMM        1427711603   COMM   COMM  Community Coin  Community Coin (COMM)
# CRYPT       1427711654  CRYPT  CRYPT       CryptCoin      CryptCoin (CRYPT)
# CTO         1433498561    CTO    CTO          Crypto           Crypto (CTO)
# CTX         1620380827    CTX    CTX         Cryptex          Cryptex (CTX)
# KART        1652882490   KART   KART     Dragon Kart     Dragon Kart (KART)
#
#                                              Description AssetTokenStatus  \
# 42     Everything about 42 coin is 42 - apart from th...              N/A
# 300    300 token is an ERC20 token. This Token was cr...              N/A
# 365    365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404    404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 433    433 Token is a decentralised soccer platform t...         Finished
# ...                                                  ...              ...
# COMM   Community Coin is a fully premined coin with a...              N/A
# CRYPT  CryptCoin (CRYPT) is an X11 altcoin - a third ...              N/A
# CTO    Crypto is a decentralized cryptocurrency desig...              N/A
# CTX    Cryptex is focused on building innovative, ope...              N/A
# KART   Dragon Kart is a 3D racing e-sport game built ...              N/A
#
#        ... MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42     ...        42             0            0           0   blockchain
# 300    ...       300             0            0           0        token
# 365    ...        -1             0            0           0   blockchain
# 404    ...        -1             0            0           0   blockchain
# 433    ...       NaN           NaN          NaN         NaN          NaN
# ...    ...       ...           ...          ...         ...          ...
# COMM   ...       NaN           NaN          NaN         NaN          NaN
# CRYPT  ...         0             0            0           0          NaN
# CTO    ...       NaN           NaN          NaN         NaN          NaN
# CTX    ...        -1             0            0           0        token
# KART   ...         0             0            0           0        token
#
#       AlgorithmType Difficulty BuiltOn  \
# 42           scrypt   0.440859     NaN
# 300             NaN        NaN     ETH
# 365             NaN        NaN     NaN
# 404             NaN        NaN     NaN
# 433             NaN        NaN     NaN
# ...             ...        ...     ...
# COMM            NaN        NaN     NaN
# CRYPT           NaN        NaN     NaN
# CTO             NaN        NaN     NaN
# CTX             NaN        NaN     ETH
# KART            NaN        NaN     NaN
#
#                              SmartContractAddress DecimalPoints
# 42                                            NaN           NaN
# 300    0xaec98a708810414878c3bcdf46aad31ded4a4557            18
# 365                                           NaN           NaN
# 404                                           NaN           NaN
# 433                                           NaN           NaN
# ...                                           ...           ...
# COMM                                          NaN           NaN
# CRYPT                                         NaN           NaN
# CTO                                           NaN           NaN
# CTX    0x321c2fe4446c7c963dc41dd58879af648838f98d            18
# KART                                          NaN           NaN
#
# [8280 rows x 36 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','MaxSupply']]

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df['IsTrading'] == True]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df['Algorithm'] != "N/A"]
crypto_df
# Out:
#              CoinName Algorithm IsTrading ProofType TotalCoinsMined MaxSupply
# 42            42 Coin    Scrypt      True   PoW/PoS       41.999952        42
# 365           365Coin       X11      True   PoW/PoS               0        -1
# 404           404Coin    Scrypt      True   PoW/PoS               0        -1
# 611         SixEleven   SHA-256      True       PoW               0         0
# 808               808   SHA-256      True   PoW/PoS               0         0
# ...               ...       ...       ...       ...             ...       ...
# BUN         BunnyCoin    Scrypt      True       PoW             NaN       NaN
# CHILD       ChildCoin       X11      True       PoW             NaN       NaN
# COMM   Community Coin    Scrypt      True   PoW/PoS             NaN       NaN
# CRYPT       CryptCoin       X11      True       PoW               0         0
# CTO            Crypto   Lyra2RE      True       PoW             NaN       NaN
#
# [1644 rows x 6 columns]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns="IsTrading")

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna(axis=0, how='any')
crypto_df
# Out:
#           CoinName     Algorithm ProofType  TotalCoinsMined  MaxSupply
# 42         42 Coin        Scrypt   PoW/PoS        41.999952         42
# 365        365Coin           X11   PoW/PoS                0         -1
# 404        404Coin        Scrypt   PoW/PoS                0         -1
# 611      SixEleven       SHA-256       PoW                0          0
# 808            808       SHA-256   PoW/PoS                0          0
# ...            ...           ...       ...              ...        ...
# NEO            NEO       dBFT2.0       N/A        100000000  100000000
# OXYC       Oxycoin          DPoS      DPoS    1122382283.37         -1
# AUR          AUREO  BEP-20 Token       N/A  19769313.742959   21000000
# BTCR   BitCurrency        Scrypt       PoS                0         -1
# CRYPT    CryptCoin           X11       PoW                0          0
#
# [709 rows x 5 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df['TotalCoinsMined'] > 0]
crypto_df.head(20)
# Out:
#                   CoinName    Algorithm     ProofType       TotalCoinsMined  \
# 42                 42 Coin       Scrypt       PoW/PoS             41.999952
# NSR               NuShares          PoS           PoS       6177926685.8373
# TRI         Triangles Coin          X13       PoW/PoS         191624.022943
# CMTC             CometCoin       Scrypt           PoW                872830
# CHAT              OpenChat       Scrypt       PoW/PoS            1000000000
# PURA                  Pura          X11           PoW      188358976.839698
# ADK           Aidos Kuneen        IMesh           PoW              25000000
# DAPS             DAPS Coin       Dagger   PoW/PoS/PoA           62319462900
# FOIN                  Foin      SHA-256           N/A         92631000.8161
# NVL                 Nevula        NEP-5           N/A           40000000000
# VEIL                  VEIL        X16RT       PoW/PoS      119516479.714871
# RVC      Ravencoin Classic         X16R           PoW    10501536386.860544
# XDNA                  XDNA          HEX       PoW/PoS               8830765
# WBBC               Wibcoin      SHA-256           PoW  1000016730264.435059
# REV                 Revain     Multiple           N/A    85056346011.834015
# TPAY              TokenPay      POS 3.0           PoS              21880393
# ETZ              EtherZero       Ethash           PoW          228471761.95
# NAX                NextDAO  NRC20 Token           N/A     2346227894.036207
# QRK              QuarkCoin        Quark       PoW/PoS      279715378.169586
# UEC   United Emirates Coin       Scrypt           N/A              20000000
#
#                  MaxSupply
# 42                      42
# NSR                      0
# TRI                      0
# CMTC                     0
# CHAT                    -1
# PURA                    -1
# ADK                      0
# DAPS           70000000000
# FOIN             100000000
# NVL            40000000000
# VEIL             300000000
# RVC            21000000000
# XDNA                     0
# WBBC  1000016730264.435059
# REV                     -1
# TPAY              25000000
# ETZ                     -1
# NAX            10000000000
# QRK                     -1
# UEC                     -1

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.iloc[:] != "N/A"].dropna()
crypto_df
# Out:
#             CoinName Algorithm ProofType     TotalCoinsMined  MaxSupply
# 42           42 Coin    Scrypt   PoW/PoS           41.999952         42
# NSR         NuShares       PoS       PoS     6177926685.8373          0
# TRI   Triangles Coin       X13   PoW/PoS       191624.022943          0
# CMTC       CometCoin    Scrypt       PoW              872830          0
# CHAT        OpenChat    Scrypt   PoW/PoS          1000000000         -1
# ...              ...       ...       ...                 ...        ...
# RDD         Reddcoin    Scrypt   PoW/PoS  30966300704.728371         -1
# NMC         Namecoin   SHA-256       PoW          18157737.5         -1
# NANO            Nano   Blake2b       PoW           133248290  133248290
# NAV          NavCoin       X13   PoW/PoS     73506978.423581         -1
# OXYC         Oxycoin      DPoS      DPoS       1122382283.37         -1
#
# [140 rows x 5 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
Coin_name = crypto_df[['CoinName']]
Coin_name
# Out:
#             CoinName
# 42           42 Coin
# NSR         NuShares
# TRI   Triangles Coin
# CMTC       CometCoin
# CHAT        OpenChat
# ...              ...
# RDD         Reddcoin
# NMC         Namecoin
# NANO            Nano
# NAV          NavCoin
# OXYC         Oxycoin
#
# [140 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=['CoinName'])
crypto_df
# Out:
#      Algorithm ProofType     TotalCoinsMined  MaxSupply
# 42      Scrypt   PoW/PoS           41.999952         42
# NSR        PoS       PoS     6177926685.8373          0
# TRI        X13   PoW/PoS       191624.022943          0
# CMTC    Scrypt       PoW              872830          0
# CHAT    Scrypt   PoW/PoS          1000000000         -1
# ...        ...       ...                 ...        ...
# RDD     Scrypt   PoW/PoS  30966300704.728371         -1
# NMC    SHA-256       PoW          18157737.5         -1
# NANO   Blake2b       PoW           133248290  133248290
# NAV        X13   PoW/PoS     73506978.423581         -1
# OXYC      DPoS      DPoS       1122382283.37         -1
#
# [140 rows x 4 columns]

# %%
# Create dummy variables for text features
dummy = pd.get_dummies(data=crypto_df,columns=['Algorithm','ProofType'])

# %%
# Standardize data
scaler = StandardScaler()
dummy_scaled = scaler.fit_transform(dummy)

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
pcs_transform = pca.fit_transform(dummy_scaled)

# %%
# Create a DataFrame with the principal components data
pca_df = pd.DataFrame(pcs_transform, columns=['Feature_1','Feature_2',"Feature_3"],index=crypto_df.index)
pca_df
# Out:
#       Feature_1  Feature_2  Feature_3
# 42     0.222853  -1.326063  -1.343659
# NSR    0.696264  -1.169297  -0.312067
# TRI    0.654795  -1.974567  -1.626911
# CMTC  -0.853521   0.447471  -0.364627
# CHAT   0.222857  -1.326059  -1.343659
# ...         ...        ...        ...
# RDD    0.223001  -1.325943  -1.343666
# NMC   -1.263204   1.280477   0.162597
# NANO  -1.218753   1.246341   0.226203
# NAV    0.654796  -1.974567  -1.626911
# OXYC   3.456048   1.413754  -0.044389
#
# [140 rows x 3 columns]

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    mean_model = KMeans(n_clusters=i, random_state=32)
    mean_model.fit(pca_df)
    inertia.append(mean_model.inertia_)


# Create the Elbow Curve using hvPlot
elbow = {"k": k, "inertia": inertia}
elbow_df = pd.DataFrame(elbow)
elbow_df.hvplot(x="k", y="inertia")
# elbow_df[elbow_df['k'] == elbow_df['k'].max()]
# Out:
# c:\Users\Administrator\anaconda3\envs\pyvizenv\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   "KMeans is known to have a memory leak on Windows "
# :Curve   [k]   (inertia)

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
K_mugga = KMeans(n_clusters=4, random_state=22)
# Fit the model
K_mugga.fit(pca_df)
# Predict clusters
predictions = K_mugga.predict(pca_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
combined_df = pd.concat([pca_df, crypto_df],axis=1,sort=False)
combined_df['cluster'] = K_mugga.labels_
combined_df
# Out:
#       Feature_1  Feature_2  Feature_3 Algorithm ProofType     TotalCoinsMined  \
# 42     0.222853  -1.326063  -1.343659    Scrypt   PoW/PoS           41.999952
# NSR    0.696264  -1.169297  -0.312067       PoS       PoS     6177926685.8373
# TRI    0.654795  -1.974567  -1.626911       X13   PoW/PoS       191624.022943
# CMTC  -0.853521   0.447471  -0.364627    Scrypt       PoW              872830
# CHAT   0.222857  -1.326059  -1.343659    Scrypt   PoW/PoS          1000000000
# ...         ...        ...        ...       ...       ...                 ...
# RDD    0.223001  -1.325943  -1.343666    Scrypt   PoW/PoS  30966300704.728371
# NMC   -1.263204   1.280477   0.162597   SHA-256       PoW          18157737.5
# NANO  -1.218753   1.246341   0.226203   Blake2b       PoW           133248290
# NAV    0.654796  -1.974567  -1.626911       X13   PoW/PoS     73506978.423581
# OXYC   3.456048   1.413754  -0.044389      DPoS      DPoS       1122382283.37
#
#       MaxSupply  cluster
# 42           42        2
# NSR           0        2
# TRI           0        2
# CMTC          0        0
# CHAT         -1        2
# ...         ...      ...
# RDD          -1        2
# NMC          -1        0
# NANO  133248290        0
# NAV          -1        2
# OXYC         -1        3
#
# [140 rows x 8 columns]

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
scale = MinMaxScaler()
series = scale.fit_transform(combined_df[['TotalCoinsMined','MaxSupply']])
series_df = pd.DataFrame(series, columns=['TotalCoinsMined','MaxSupply'], index=combined_df.index)
series_df['cluster'] = combined_df['cluster']
series_df['CoinName'] = Coin_name
series_df['Algorithm'] = combined_df['Algorithm']
series_df
# Out:
#       TotalCoinsMined     MaxSupply  cluster        CoinName Algorithm
# 42       0.000000e+00  2.047619e-12        2         42 Coin    Scrypt
# NSR      6.240330e-06  4.761905e-14        2        NuShares       PoS
# TRI      1.935172e-10  4.761905e-14        2  Triangles Coin       X13
# CMTC     8.816040e-10  4.761905e-14        0       CometCoin    Scrypt
# CHAT     1.010101e-06  0.000000e+00        2        OpenChat    Scrypt
# ...               ...           ...      ...             ...       ...
# RDD      3.127909e-05  0.000000e+00        2        Reddcoin    Scrypt
# NMC      1.834111e-08  0.000000e+00        0        Namecoin   SHA-256
# NANO     1.345942e-07  6.345157e-06        0            Nano   Blake2b
# NAV      7.424943e-08  0.000000e+00        2         NavCoin       X13
# OXYC     1.133719e-06  0.000000e+00        3         Oxycoin      DPoS
#
# [140 rows x 5 columns]

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
series_df.hvplot.scatter(x="TotalCoinsMined", y="MaxSupply",by='cluster',hover_cols='CoinName')
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [TotalCoinsMined]   (MaxSupply,CoinName)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
combined_df['CoinName'] = series_df["CoinName"]
tradable_table = combined_df[["CoinName", "Algorithm", "MaxSupply","TotalCoinsMined", "cluster","ProofType"]].hvplot.table()

# %%
# Print the total number of tradable cryptocurrenciescombined_df
print(len(tradable_table))
# Out:
# 140
